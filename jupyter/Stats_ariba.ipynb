# %%
import os
import pandas as pd
import numpy as np
import pandas_profiling
import seaborn as sns
import matplotlib.pyplot as plt


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
ecoPlasFile = "/processing_Data/antibioticos/mperezv/ANALYSIS/ECOCARSUR/06-ariba/summary/out.summaryplasmidfinder.csv"
ecoResFile = "/processing_Data/antibioticos/mperezv/ANALYSIS/ECOCARSUR/06-ariba/summary/out.summarysrst2_argannot.csv"
kpnPlasFile = "/processing_Data/antibioticos/mperezv/ANALYSIS/KPNCARSUR/06-ariba/summary/out.summaryplasmidfinder.csv"
kpnResFile = "/processing_Data/antibioticos/mperezv/ANALYSIS/KPNCARSUR/06-ariba/summary/out.summarysrst2_argannot.csv"

# %%
def import_ariba(file):
    df = pd.read_csv(file, sep=",")
    df.columns = df.columns.str.replace('.match',"")
    df.name = df.name.str.replace('/out.*\.tsv', "")
    df.name = df.name.str.replace('\.\./run/', "")
    df01 = df.replace(to_replace =["no", "yes"], value =[0,1])
    df01.set_index('name', inplace=True)
    return df01

# %%
def print_stats(list_sum):
    print("Nunero total:%s, Maximo:%s, , Minimo:%s, Media:%.2f" % (len(list_sum), max(list_sum), min(list_sum), list_sum.mean()))

# %%
def calculate_distance_stat(dataframe, list_sample=False):
    if list_sample != False:
        dataframe = dataframe.loc[list_sample,list_sample]
    stacked_df = dataframe.stack()
    #np.nanmean(dfdist.loc[cluster_test,cluster_test].values)
    #np.nanmin(dfdist.loc[cluster_test,cluster_test].values)
    #np.nanmax(dfdist.loc[cluster_test,cluster_test].values)
    mean_distance = stacked_df.mean(skipna = True)
    min_distance = stacked_df.min(skipna = True)
    max_distance = stacked_df.max(skipna = True)
    print("Este cluster tiene %s muestras, con una distancia media de %.2f, rango [%.0f - %.0f]" % (len(dataframe.columns), mean_distance, min_distance, max_distance))

# %%
ecoplas = import_ariba(ecoPlasFile)

# %%
df01
# Out:
#           Col156  Col440I  Col440II  Col_MG828_  Col_pHAD28_  FIA_pBK30683_+  \
# name
# A0503ECO       0        0         0           0            0               0
# A0510ECO       0        0         0           1            0               0
# A0609ECO       0        0         0           0            0               0
# A1201ECO       0        0         1           0            1               0
# A1204ECO       0        0         1           0            1               0
# A1205ECO       0        1         0           0            0               0
# A1210ECO       0        1         0           0            0               0
# B0106ECO       0        0         0           1            0               0
# B0406          0        0         0           0            0               0
# C0003          1        0         1           0            1               1
# D0002          0        0         0           0            0               0
# ...

# %%
ecoplas
# Out:
#           Col156  Col440I  Col440II  Col_MG828_  Col_pHAD28_  FIA_pBK30683_+  \
# name
# A0503ECO       0        0         0           0            0               0
# A0510ECO       0        0         0           1            0               0
# A0609ECO       0        0         0           0            0               0
# A1201ECO       0        0         1           0            1               0
# A1204ECO       0        0         1           0            1               0
# A1205ECO       0        1         0           0            0               0
# A1210ECO       0        1         0           0            0               0
# B0106ECO       0        0         0           1            0               0
# B0406          0        0         0           0            0               0
# C0003          1        0         1           0            1               1
# D0002          0        0         0           0            0               0
# ...

# %%
#df01.describe()

# %%
#df01.info()

# %%
list_plas_eco = ecoplas.sum(axis = 0, skipna = True)
list_plas_eco
# Out:
# Col156               4
# Col440I              2
# Col440II             3
# Col_MG828_           3
# Col_pHAD28_          3
# FIA_pBK30683_+       3
# Inc-                10
# Inc-_1               1
# IncB_O_K_Z           1
# IncFI-               6
# IncFIA               3
# IncFIB_AP001918_     7
# IncFIB_K_            1
# IncFIB_pQil_         2
# IncFII_K_            3
# IncFII_p-            3
# IncFII_pKP91_        1
# IncI-                4
# IncI2-               1
# IncN                 2
# IncR                 1
# IncX1                2
# IncX1_1              1
# IncX4                1
# IncY                 1
# dtype: int64

# %%
print_stats(list_plas_eco)
# Out:
# Nunero total:25, Maximo:10, , Minimo:1, Media:2.76

# %%
list_plas_sample_eco = ecoplas.sum(axis = 1, skipna = True)
list_plas_sample_eco
# Out:
# name
# A0503ECO     4
# A0510ECO     3
# A0609ECO     2
# A1201ECO     3
# A1204ECO     3
# A1205ECO     3
# A1210ECO     3
# B0106ECO     2
# B0406        3
# C0003       11
# D0002        1
# D0004        4
# D0202        9
# E0008        5
# E0202       10
# G0402        3
# dtype: int64

# %%
print_stats(list_plas_sample_eco)
# Out:
# Nunero total:16, Maximo:11, , Minimo:1, Media:4.31

# %%
#pd.pivot_table(df01, index=df01.index.name, aggfunc='sum', margins=True)

# %%
#pandas_profiling.ProfileReport(df01)

# %%
#pd.melt(df01, value_vars=['name'])
#df01.melt(id_vars=['name', 'State'], value_vars=['Mango', 'Orange', 'Watermelon'], var_name='Fruit', value_name='Pounds')

# %%
ecores = import_ariba(ecoResFile)

# %%
ecores.head(5)
# Out:
#           AMPH_Ecoli_Bla  Aac3_IIa_AGly  AacAad_AGly_3  AadA4_5_AGly  \
# name
# A0503ECO               1              0              0             0
# A0510ECO               1              0              0             0
# A0609ECO               1              1              0             0
# A1201ECO               1              0              0             0
# A1204ECO               1              0              0             0
#
#           AadA_AGly  AadA_AGly_2  AadB_AGly  AmpC1_Ecoli_Bla  AmpC2_Ecoli_Bla  \
# name
# A0503ECO          1            1          0                0                1
# A0510ECO          0            0          0                1                1
# A0609ECO          0            0          0                1                1
# A1201ECO          0            0          0                0                1
# A1204ECO          0            0          0                0                1
#
# ...

# %%
list_res_eco = ecores.sum(axis = 0, skipna = True)
list_res_eco
# Out:
# AMPH_Ecoli_Bla     15
# Aac3_IIa_AGly       4
# AacAad_AGly_3       3
# AadA4_5_AGly        2
# AadA_AGly           3
# AadA_AGly_2         3
# AadB_AGly           1
# AmpC1_Ecoli_Bla     9
# AmpC2_Ecoli_Bla    15
# Aph3__Ia_AGly       2
# Arr_Rif             1
# CMY_Bla             1
# CTX_M_1_Bla         5
# CTX_M_9_Bla         1
# CatBx_Phe           4
# DfrA16_Tmt          1
# DfrA25_Tmt          1
# DfrA5_Tmt           2
# DfrA5_Tmt_1         1
# DfrA7_Tmt           2
# DfrA_Tmt            1
# DfrB_Tmt            1
# KPC_1_Bla           2
# Mcr1_Colistin       1
# MphA_MLS            2
# MphE_MLS            1
# MrdA_Bla           15
# MsrE_MLS            1
# OXA_1_Bla           5
# OXA_48_Bla         13
# QnrB_Flq_1          1
# Qnr_A_Flq           1
# Qnr_S_Flq_1         2
# StrA_AGly           5
# StrB_AGly           5
# SulII_Sul           5
# SulI_Sul            5
# TEM_1D_Bla         10
# TetA_Tet            6
# TetB_Tet            3
# VIM_1_Bla           2
# dtype: int64

# %%
print_stats(list_res_eco)
# Out:
# Nunero total:41, Maximo:15, , Minimo:1, Media:3.98

# %%
list_res_sample_eco = ecores.sum(axis = 1, skipna = True)
list_res_sample_eco
# Out:
# name
# A0503ECO     7
# A0510ECO     7
# A0609ECO     7
# A1201ECO     6
# A1204ECO     9
# A1205ECO     5
# A1210ECO     4
# B0106ECO     8
# B0406       16
# C0003       16
# D0002       12
# D0004       17
# D0202        5
# E0008       16
# E0202       10
# G0402       18
# dtype: int64

# %%
print_stats(list_res_sample_eco)
# Out:
# Nunero total:16, Maximo:18, , Minimo:4, Media:10.19

# %%
kpnplas = import_ariba(kpnPlasFile)

# %%
kpnplas.head(5)
# Out:
#           Col156  Col440I  Col440II  ColRNAI  Col_BS512_  Col_MG828_  \
# name
# A0101KPN       0        0         1        0           0           0
# A0102KPN       0        0         1        0           0           1
# A0103KPN       0        0         0        0           0           1
# A0104KPN       0        0         0        0           0           1
# A0105KPN       0        1         1        0           0           0
#
#           Col_pHAD28_  ColpVC  FIA_pBK30683_+  Inc-  Inc-_1  IncFI-  IncFIA  \
# name
# A0101KPN            1       0               0     0       0       0       0
# A0102KPN            1       1               0     1       0       0       0
# A0103KPN            1       1               0     1       0       0       0
# A0104KPN            1       1               0     1       0       0       0
# A0105KPN            1       1               0     1       0       0       0
#
#           IncFIB_AP001918_  IncFIB_K_  IncFIB_pKPHS1_  IncFIB_pNDM_Mar_  \
# ...

# %%
list_plas_kpn = kpnplas.sum(axis = 0, skipna = True)
list_plas_kpn
# Out:
# Col156                 2
# Col440I               33
# Col440II              23
# ColRNAI               49
# Col_BS512_             1
# Col_MG828_             9
# Col_pHAD28_           72
# ColpVC                23
# FIA_pBK30683_+         8
# Inc-                 131
# Inc-_1                 1
# IncFI-                 1
# IncFIA                 3
# IncFIB_AP001918_       1
# IncFIB_K_            192
# IncFIB_pKPHS1_         3
# IncFIB_pNDM_Mar_      50
# IncFIB_pQil_          40
# IncFII_K_            165
# IncFII_p-              1
# IncFII_pKP91_         27
# IncFII_pKPX1_          2
# IncHI1B_pNDM_MAR_     14
# IncHI2                 5
# IncHI2A                5
# IncI-                  3
# IncM1                  3
# IncN                   7
# IncR                  79
# IncU                   1
# IncX1                  2
# IncX1_1                2
# IncX3                 12
# IncX3_pEC14_           1
# p0111                  1
# pKPC_CAV1321           1
# dtype: int64

# %%
print_stats(list_plas_kpn)
# Out:
# Nunero total:36, Maximo:192, , Minimo:1, Media:27.03

# %%
list_plas_sample_kpn = kpnplas.sum(axis = 1, skipna = True)
list_plas_sample_kpn
# Out:
# name
# A0101KPN    6
# A0102KPN    6
# A0103KPN    6
# A0104KPN    7
# A0105KPN    9
#            ..
# G0301       3
# G0401       3
# G0403       4
# G0501       7
# G0503       4
# Length: 234, dtype: int64

# %%
print_stats(list_plas_sample_kpn)
# Out:
# Nunero total:234, Maximo:9, , Minimo:0, Media:4.16

# %%
'''number_of_resistance = 0
list_of_samples_with_res = list_plas_sample_kpn.tolist().index(number_of_resistance)
print(list_of_samples_with_res)
print("===========================")
kpnplas.iloc[list_of_samples_with_res]
'''
# Out:
# 'number_of_resistance = 0\nlist_of_samples_with_res = list_plas_sample_kpn.tolist().index(number_of_resistance)\nprint(list_of_samples_with_res)\nprint("===========================")\nkpnplas.iloc[list_of_samples_with_res]\n'

# %%
kpnres = import_ariba(kpnResFile)

# %%
kpnres.filter(regex='KPC.*', axis=1)
# Out:
#           KPC_1_Bla
# name
# A0101KPN          1
# A0102KPN          0
# A0103KPN          0
# A0104KPN          0
# A0105KPN          1
# A0106KPN          0
# A0107KPN          0
# A0108KPN          0
# A0109KPN          1
# A0110KPN          0
# A0301KPN          0
# A0302KPN          0
# A0303KPN          0
# A0304KPN          0
# A0305KPN          0
# A0306KPN          0
# A0401KPN          0
# A0402KPN          0
# A0501KPN          0
# A0502KPN          0
# A0504KPN          0
# A0505KPN          0
# A0506KPN          0
# A0507KPN          0
# A0508KPN          1
# A0509KPN          0
# A0601KPN          0
# A0602KPN          0
# A0603KPN          0
# A0604KPN          0
# A0605KPN          0
# A0606KPN          0
# A0607KPN          0
# A0608KPN          0
# A0610KPN          0
# A0701KPN          0
# A0702KPN          0
# A0703KPN          0
# A0704KPN          0
# A0705KPN          0
# A0706KPN          0
# A0707KPN          0
# A0708KPN          0
# A0709KPN          0
# ...

# %%
list_res_kpn = kpnres.sum(axis = 0, skipna = True)
#for i in list_res_kpn:
#    print(i)
list_res_kpn.to_csv('/home/pjsola/google-drive-pedroscampoy/0_CNM_ISCIII/SEIMC_2020/freq_res_KPN_perc.tab', sep='\t', header=True)

# %%
dfpercentage = list_res_kpn

# %%
dfpercentage.iloc[1] = dfpercentage.iloc[1]/len(kpnres
# Out:
# 2

# %%
list_res_kpn
# Out:
# AMPH_Ecoli_Bla      2
# Aac3_IIa_AGly      95
# AacAad_AGly         7
# AacAad_AGly_3     158
# AadA4_5_AGly        2
#                  ...
# TEM_1D_Bla        112
# TetA_Tet           53
# TetB_Tet            1
# TetD_Tet            7
# VIM_1_Bla          15
# Length: 61, dtype: int64

# %%
len(kpnres.index)
# Out:
# 229

# %%
print_stats(list_res_kpn)
# Out:
# Nunero total:61, Maximo:219, , Minimo:1, Media:46.20

# %%
number_of_resistance = 1
#indices = [i for i, x in enumerate(my_list) if x == "whatever"]
#list_of_samples_with_res = list_res_kpn.tolist().index(number_of_resistance)
list_of_samples_with_res = [i for i, x in enumerate(list_res_kpn.tolist()) if x == number_of_resistance]
print(list_of_samples_with_res)
print("===========================")
kpnres.iloc[:,list_of_samples_with_res]
# Out:
# [12, 15, 22, 23, 25, 28, 44, 46, 51, 58]
# ...
#           AphA15_AGly  CMY_Bla  CmlA_Phe  DHA_Bla  DfrA1_Tmt_1  DfrA5_Tmt_1  \
# name
# A0101KPN            0        0         0        0            0            0
# A0102KPN            0        0         0        0            0            0
# A0103KPN            0        0         0        0            0            0
# A0104KPN            0        0         0        0            0            0
# A0105KPN            0        0         0        0            0            0
# ...               ...      ...       ...      ...          ...          ...
# G0301               0        0         0        0            0            0
# G0401               0        0         0        0            0            0
# G0403               0        0         0        0            0            0
# G0501               0        0         0        0            0            0
# G0503               0        0         0        0            0            0
#
# ...

# %%
kpnres.shape
# Out:
# (234, 61)

# %%
list_to_remove = ['C0202', 'C0204', 'C0206', 'C0207', 'E0005']

# %%
kpnres.loc[list_to_remove]
# Out:
#        AMPH_Ecoli_Bla  Aac3_IIa_AGly  AacAad_AGly  AacAad_AGly_3  \
# name
# C0202               0              0            0              0
# C0204               0              0            0              0
# C0206               0              0            0              0
# C0207               0              0            0              0
# E0005               0              0            0              0
#
#        AadA4_5_AGly  AadA_AGly  AadA_AGly_2  AadB_AGly  AmpC1_Ecoli_Bla  \
# name
# C0202             0          0            0          0                0
# C0204             0          0            0          0                0
# C0206             0          0            0          0                0
# C0207             0          0            0          0                0
# E0005             0          0            0          0                0
#
#        AmpC2_Ecoli_Bla  AmpH_Bla  Aph3__Ia_AGly  AphA15_AGly  AphA6_AGly  \
# name
# ...

# %%
kpnres.drop(list_to_remove, inplace=True)

# %%
kpnres.shape
# Out:
# (229, 61)

# %%
list_res_sample_kpn = kpnres.sum(axis = 1, skipna = True)
list_res_sample_kpn
# Out:
# name
# A0101KPN    15
# A0102KPN     5
# A0103KPN    10
# A0104KPN     5
# A0105KPN    16
#             ..
# G0301        5
# G0401       19
# G0403       19
# G0501       14
# G0503       15
# Length: 229, dtype: int64

# %%
print_stats(list_res_sample_kpn)
# Out:
# Nunero total:229, Maximo:27, , Minimo:2, Media:12.31

# %%
number_of_resistance = 0
#indices = [i for i, x in enumerate(my_list) if x == "whatever"]
#list_of_samples_with_res = list_res_kpn.tolist().index(number_of_resistance)
list_of_samples_with_res = [i for i, x in enumerate(list_res_sample_kpn.tolist()) if x == number_of_resistance]
print(list_of_samples_with_res)
print("===========================")
kpnres.iloc[list_of_samples_with_res]
# Out:
# [174, 176, 178, 179, 200]
# ...
#        AMPH_Ecoli_Bla  Aac3_IIa_AGly  AacAad_AGly  AacAad_AGly_3  \
# name
# C0202               0              0            0              0
# C0204               0              0            0              0
# C0206               0              0            0              0
# C0207               0              0            0              0
# E0005               0              0            0              0
#
#        AadA4_5_AGly  AadA_AGly  AadA_AGly_2  AadB_AGly  AmpC1_Ecoli_Bla  \
# name
# C0202             0          0            0          0                0
# C0204             0          0            0          0                0
# C0206             0          0            0          0                0
# C0207             0          0            0          0                0
# E0005             0          0            0          0                0
#
#        AmpC2_Ecoli_Bla  AmpH_Bla  Aph3__Ia_AGly  AphA15_AGly  AphA6_AGly  \
# name
# ...

# %%
sns.clustermap(kpnres, annot=False, cmap="YlGnBu", figsize=(100, 100))
plt.savefig('/processing_Data/antibioticos/mperezv/ANALYSIS/KPNCARSUR/06-ariba/summary/out.summarysrst2_argannot.cluster.png', format="png")

# %% [markdown]
# # READ DISTANCE MATRIX

# %%
dfdist = pd.read_csv('/processing_Data/antibioticos/mperezv/ANALYSIS/KPNCARSUR/08-snippy/clean.core.mega_distance.csv', index_col=0,  sep=",")

# %%
dfdist
# Out:
#            A0101KPN  A0102KPN  A0103KPN  A0104KPN  A0105KPN  A0106KPN  \
# A0101KPN        NaN       NaN       NaN       NaN       NaN       NaN
# A0102KPN       65.0       NaN       NaN       NaN       NaN       NaN
# A0103KPN      212.0     170.0       NaN       NaN       NaN       NaN
# A0104KPN      101.0      71.0     213.0       NaN       NaN       NaN
# A0105KPN        6.0      65.0     210.0     104.0       NaN       NaN
# ...             ...       ...       ...       ...       ...       ...
# G0301       20509.0   20489.0   20624.0   20463.0   20482.0   14600.0
# G0403       22034.0   22049.0   22171.0   22007.0   22016.0   16567.0
# G0501       21850.0   21813.0   21977.0   21810.0   21838.0   16312.0
# G0503         112.0     116.0     255.0     146.0     115.0   15155.0
# Reference   22352.0   22310.0   22448.0   22267.0   22295.0   16715.0
#
#            A0107KPN  A0108KPN  A0109KPN  A0110KPN  A0301KPN  A0302KPN  \
# ...

# %%
pairwise_test = dfdist.stack().min()

# %%
pairwise_test
# Out:
# 3.0

# %%
pairwise_test.to_csv('/home/pjsola/google-drive-pedroscampoy/0_CNM_ISCIII/SEIMC_2020/pairwise_terst_kpn.tab', sep='\t', index=True)
# Out:
# /home/pjsola/.conda/envs/develop/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
max(dfdist.max(skipna = True).tolist())
# Out:
# 24240.0

# %%
min(dfdist.min(skipna = True).tolist())
# Out:
# 3.0

# %%
dfdist.mean(skipna = True).mean()
# Out:
# 14513.79735551164

# %%
dfst = pd.read_excel('/home/pjsola/google-drive-pedroscampoy/0_CNM_ISCIII/SEIMC_2020/CAR_SUR_cgWGS.xlsx')

# %%
dfst.head()
# Out:
#    #Missing values in Distance Columns  Perc. Good Targets  \
# 0                                   10                99.6
# 1                                    3                99.9
# 2                                  102                95.7
# 3                                   11                99.6
# 4                                   11                99.5
#
#   Avg. Coverage (Assembled)  Approximated Genome Size (Mbases)  \
# 0                         ?                                5.4
# 1                         ?                                5.5
# 2                         ?                                5.2
# 3                         ?                                5.7
# 4                         ?                                5.5
#
#    Top Species Match Identity      Top Species Match Sample ID           ST  \
# 0                        1.00  Klebsiella pneumoniae  A1507KPN            ?
# ...

# %%
dfbbdd = pd.read_excel('/home/pjsola/google-drive-pedroscampoy/0_CNM_ISCIII/SEIMC_2020/BBDD_CARBA_ES-19_ULTIMA.xlsx')

# %%
dfbbdd.head()
# Out:
#   Centro      Cepa Cepa CNM     ST    Provincia Nº Hospital  \
# 0    A01  A0101kpn   K11143  307.0  Guadalajara    85330209
# 1    A01  A0102kpn   K11145  307.0  Guadalajara    82451307
# 2    A01  A0103kpn   K11146  307.0  Guadalajara    72425629
# 3    A01  A0104kpn   K11147  307.0  Guadalajara    72428558
# 4    A01  A0105kpn   K11150  307.0  Guadalajara    88083674
#
#                       Hospital       Edad     Fecha nacimiento    Sexo  \
# 0  H Universitario Guadalajara  68.246407  1950-11-15 00:00:00  Hombre
# 1  H Universitario Guadalajara  79.011636  1940-02-10 00:00:00  Hombre
# 2  H Universitario Guadalajara  91.003422  1928-02-18 00:00:00   Mujer
# 3  H Universitario Guadalajara  97.809719  1921-05-16 00:00:00   Mujer
# 4  H Universitario Guadalajara  61.119781  1958-01-27 00:00:00   Mujer
#
#   Fecha toma muestra Fecha recepción  Nº CNM       Especie  \
# 0         2019-02-13      2019-04-04  440014  K pneumoniae
# ...

# %%
dfbbdd.groupby(['ST', 'Provincia']).size()
# Out:
# ST     Provincia
# 11.0   Alicante               1
#        Badajoz                1
#        Barcelona              1
#        Burgos                 2
#        Cáceres                1
#        Cádiz                  1
#        Guadalajara            1
#        La Rioja               1
#        Leon                   6
#        Madrid                 6
#        Segovia                7
#        Sta. Cruz Tenerife     1
#        Valladolid             8
#        Vizcaya                1
#        Zamora                 1
#        Ávila                  1
# 15.0   Huelva                 1
#        Leon                   1
#        Lugo                   9
#        Madrid                 5
#        Málaga                 4
#        Sevilla                2
#        Sta. Cruz Tenerife     8
#        Vizcaya                1
#        Zaragoza               1
# 307.0  Albacete               1
#        Alicante               2
#        Almería                1
# ...

# %%
dfbbdd.groupby('ST').Provincia.count()
# Out:
# ST
# 11.0     40
# 15.0     32
# 307.0    62
# 512.0    22
# Name: Provincia, dtype: int64

# %%
dfbbdd.groupby('ST')['Provincia'].nunique()
# Out:
# ST
# 11.0     16
# 15.0      9
# 307.0    16
# 512.0     6
# Name: Provincia, dtype: int64

# %%
dfbbdd.groupby('ST')['Provincia'].value_counts()
# Out:
# ST     Provincia
# 11.0   Valladolid             8
#        Segovia                7
#        Leon                   6
#        Madrid                 6
#        Burgos                 2
#        Alicante               1
#        Badajoz                1
#        Barcelona              1
#        Cáceres                1
#        Cádiz                  1
#        Guadalajara            1
#        La Rioja               1
#        Sta. Cruz Tenerife     1
#        Vizcaya                1
#        Zamora                 1
#        Ávila                  1
# 15.0   Lugo                   9
#        Sta. Cruz Tenerife     8
#        Madrid                 5
#        Málaga                 4
#        Sevilla                2
#        Huelva                 1
#        Leon                   1
#        Vizcaya                1
#        Zaragoza               1
# 307.0  Madrid                14
#        Guadalajara            9
#        Cáceres                6
# ...

# %%
dfbbdd.groupby('ST').nunique()
# Out:
#        Centro  Cepa  Cepa CNM  ST  Provincia  Nº Hospital  Hospital  Edad  \
# ST
# 11.0       18    40        27   1         16           39        18    25
# 15.0       12    32        19   1          9           32        12    18
# 307.0      20    62        45   1         16           62        20    44
# 512.0       7    22         6   1          6           18         7     4
#
#        Fecha nacimiento  Sexo  Fecha toma muestra  Fecha recepción  Nº CNM  \
# ST
# 11.0                 25     3                  33               14      27
# 15.0                 18     2                  23                6      19
# 307.0                44     2                  44               10      45
# 512.0                 4     2                  17                1       6
#
#        Especie  Carbapenemasa reportada   Carbapenemasa CNM/NODO  \
# ST
# 11.0         2                        10                       4
# 15.0         1                         5                       2
# ...

# %%
cluster1 = dfst['Sample ID'][dfst.ST == '307'].tolist()
cluster2 = dfst['Sample ID'][dfst.ST == '11'].tolist()
cluster3 = dfst['Sample ID'][dfst.ST == '15'].tolist()
cluster4 = dfst['Sample ID'][dfst.ST == '512'].tolist()
cluster5 = dfst['Sample ID'][dfst.ST == '392'].tolist()
cluster6 = dfst['Sample ID'][dfst.ST == '147'].tolist()

# %%
remove_cluster_2 = ['B0409', 'A2608KPN', 'A1303KPN']

# %%
cluster2 = [item for item in cluster2 if item not in remove_cluster_2]

# %%
print(len(cluster1), len(cluster2), len(cluster3), len(cluster4),  len(cluster5),  len(cluster6))
# Out:
# 62 37 32 22 12 10

# %%
list_st = dfst.ST.unique().tolist()
print(list_st)
# Out:
# ['?', '? (unknown)', '101', '107', '11', '111', '13', '147', '15', '152', '17', '1963', '22', '252', '253', '258', '29', '307', '323', '3362', '37', '39', '392', '405', '4123', '437', '449', '461', '512', '6', '628', '709', '716', '870']

# %%
len(list_st)
# Out:
# 34

# %%
cluster_test = [
'A0101KPN',
'A0105KPN',
'A0109KPN',
'C0004',
'C0001',
'C0009'
]

# %%
dfdist.loc[cluster_test,cluster_test]
# Out:
#           A0101KPN  A0105KPN  A0109KPN  C0004  C0001  C0009
# A0101KPN       NaN       NaN       NaN    NaN    NaN    NaN
# A0105KPN       6.0       NaN       NaN    NaN    NaN    NaN
# A0109KPN       4.0       6.0       NaN    NaN    NaN    NaN
# C0004         20.0      23.0      21.0    NaN   21.0    NaN
# C0001         15.0      19.0      15.0    NaN    NaN    NaN
# C0009         14.0      18.0      17.0   17.0    4.0    NaN

# %%
def calculate_distance_stat(dataframe, list_sample=False):
    if list_sample != False:
        dataframe = dataframe.loc[list_sample,list_sample]
    stacked_df = dataframe.stack()
    #np.nanmean(dfdist.loc[cluster_test,cluster_test].values)
    #np.nanmin(dfdist.loc[cluster_test,cluster_test].values)
    #np.nanmax(dfdist.loc[cluster_test,cluster_test].values)
    mean_distance = stacked_df.mean(skipna = True)
    min_distance = stacked_df.min(skipna = True)
    max_distance = stacked_df.max(skipna = True)
    print("Este cluster tiene %s muestras, con una distancia media de %.2f, rango [%.0f - %.0f]" % (len(dataframe.columns), mean_distance, min_distance, max_distance))

# %%
calculate_distance_stat(dfdist)
# Out:
# Este cluster tiene 226 muestras, con una distancia media de 14546.65, rango [3 - 24240]

# %%
dfdist.loc[cluster1,cluster1].head()
# Out:
#           A0101KPN  A0102KPN  A0103KPN  A0104KPN  A0105KPN  A0107KPN  \
# A0101KPN       NaN       NaN       NaN       NaN       NaN       NaN
# A0102KPN      65.0       NaN       NaN       NaN       NaN       NaN
# A0103KPN     212.0     170.0       NaN       NaN       NaN       NaN
# A0104KPN     101.0      71.0     213.0       NaN       NaN       NaN
# A0105KPN       6.0      65.0     210.0     104.0       NaN       NaN
#
#           A0108KPN  A0109KPN  A0110KPN  A0302KPN  A0303KPN  A0304KPN  \
# A0101KPN       NaN       NaN       NaN       NaN       NaN       NaN
# A0102KPN       NaN       NaN       NaN       NaN       NaN       NaN
# A0103KPN       NaN       NaN       NaN       NaN       NaN       NaN
# A0104KPN       NaN       NaN       NaN       NaN       NaN       NaN
# A0105KPN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           A0305KPN  A0306KPN  A0508KPN  A0509KPN  A0601KPN  A0602KPN  \
# ...

# %%
dfdist.shape
# Out:
# (226, 226)

# %%
dfadist.loc[cluster3,cluster3]
# Out:
# 0         A0501KPN  A0505KPN  A0701KPN  A0702KPN  A0703KPN  A0705KPN  \
# 0
# A0501KPN       NaN       NaN       NaN       NaN       NaN       NaN
# A0505KPN     107.0       NaN       NaN       NaN       NaN       NaN
# A0701KPN      82.0      84.0       NaN       NaN       NaN       NaN
# A0702KPN      75.0      79.0      14.0       NaN       NaN       NaN
# A0703KPN      83.0      90.0      26.0      16.0       NaN       NaN
# A0705KPN      82.0      86.0      36.0      28.0      38.0       NaN
# A0707KPN      83.0      88.0      24.0      14.0       2.0      36.0
# A0708KPN      83.0      87.0      22.0      10.0      24.0      36.0
# A0709KPN      81.0      85.0       6.0      12.0      24.0      36.0
# A0710KPN      80.0      87.0      35.0      27.0      37.0      30.0
# A1501KPN     101.0      28.0      77.0      73.0      83.0      79.0
# A1803KPN      80.0      86.0      39.0      33.0      43.0      41.0
# ...

# %%
dfdist
# Out:
#            A0101KPN  A0102KPN  A0103KPN  A0104KPN  A0105KPN  A0106KPN  \
# A0101KPN        NaN       NaN       NaN       NaN       NaN       NaN
# A0102KPN       65.0       NaN       NaN       NaN       NaN       NaN
# A0103KPN      212.0     170.0       NaN       NaN       NaN       NaN
# A0104KPN      101.0      71.0     213.0       NaN       NaN       NaN
# A0105KPN        6.0      65.0     210.0     104.0       NaN       NaN
# ...             ...       ...       ...       ...       ...       ...
# G0301       20509.0   20489.0   20624.0   20463.0   20482.0   14600.0
# G0403       22034.0   22049.0   22171.0   22007.0   22016.0   16567.0
# G0501       21850.0   21813.0   21977.0   21810.0   21838.0   16312.0
# G0503         112.0     116.0     255.0     146.0     115.0   15155.0
# Reference   22352.0   22310.0   22448.0   22267.0   22295.0   16715.0
#
#            A0107KPN  A0108KPN  A0109KPN  A0110KPN  A0301KPN  A0302KPN  \
# ...

# %%
dfdist.loc[cluster3,cluster3].head()
# Out:
#           A0501KPN  A0505KPN  A0701KPN  A0702KPN  A0703KPN  A0705KPN  \
# A0501KPN       NaN       NaN       NaN       NaN       NaN       NaN
# A0505KPN     234.0       NaN       NaN       NaN       NaN       NaN
# A0701KPN     217.0     207.0       NaN       NaN       NaN       NaN
# A0702KPN     200.0     206.0      57.0       NaN       NaN       NaN
# A0703KPN     222.0     218.0      75.0      67.0       NaN       NaN
#
#           A0707KPN  A0708KPN  A0709KPN  A0710KPN  A1501KPN  A1803KPN  \
# A0501KPN       NaN       NaN       NaN       NaN       NaN       NaN
# A0505KPN       NaN       NaN       NaN       NaN       NaN       NaN
# A0701KPN       NaN       NaN       NaN       NaN       NaN       NaN
# A0702KPN       NaN       NaN       NaN       NaN       NaN       NaN
# A0703KPN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           A2205KPN  A2206KPN  A2210KPN  A2301KPN  A2302KPN  A2303KPN  \
# ...

# %%
dfdist.loc[cluster4,cluster4].head()
# Out:
#           A1001KPN  A1003KPN  A1006KPN  A1008KPN  B0004KPN  B0009KPN  C0201  \
# A1001KPN       NaN       NaN       NaN       NaN       NaN       NaN    NaN
# A1003KPN       3.0       NaN       NaN       NaN       NaN       NaN    NaN
# A1006KPN      11.0      12.0       NaN       NaN       NaN       NaN    NaN
# A1008KPN       9.0      10.0      11.0       NaN       NaN       NaN    NaN
# B0004KPN      22.0      23.0      24.0      22.0       NaN       NaN    NaN
#
#           C0203  C0205  C0208  C0209  C0210  F0407  G0006  G0007  G0102  \
# A1001KPN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# A1003KPN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# A1006KPN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# A1008KPN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# B0004KPN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#           G0103  G0105  G0201  G0202  G0203  G0205
# ...

# %%
dfdist[dfdist.columns.isin(cluster_test)]
# Out:
#           A0101KPN  A0102KPN  A0103KPN  A0104KPN  A0105KPN  A0106KPN  \
# A0101KPN       NaN       NaN       NaN       NaN       NaN       NaN
# A0105KPN       6.0      65.0     210.0     104.0       NaN       NaN
# A0109KPN       4.0      64.0     207.0     100.0       6.0   15580.0
# C0001         15.0      68.0     206.0     103.0      19.0   15572.0
# C0004         20.0      64.0     219.0     107.0      23.0   15581.0
# C0009         14.0      65.0     211.0     103.0      18.0   15588.0
#
#           A0107KPN  A0108KPN  A0109KPN  A0110KPN  A0301KPN  A0302KPN  \
# A0101KPN       NaN       NaN       NaN       NaN       NaN       NaN
# A0105KPN       NaN       NaN       NaN       NaN       NaN       NaN
# A0109KPN      81.0      76.0       NaN       NaN       NaN       NaN
# C0001         85.0      81.0      15.0      64.0   15015.0     118.0
# C0004         82.0      85.0      21.0      70.0   15024.0     113.0
# ...

# %%
dfdist.filter(cluster_test, axis=1).filter(cluster_test, axis=0)
# Out:
#           A0101KPN  A0105KPN  A0109KPN  C0004  C0001  C0009
# A0101KPN       NaN       NaN       NaN    NaN    NaN    NaN
# A0105KPN       6.0       NaN       NaN    NaN    NaN    NaN
# A0109KPN       4.0       6.0       NaN    NaN    NaN    NaN
# C0004         20.0      23.0      21.0    NaN   21.0    NaN
# C0001         15.0      19.0      15.0    NaN    NaN    NaN
# C0009         14.0      18.0      17.0   17.0    4.0    NaN

# %%
calculate_distance_stat(dfdist, cluster1)
calculate_distance_stat(dfdist, cluster2)
calculate_distance_stat(dfdist, cluster3)
calculate_distance_stat(dfdist, cluster4)
calculate_distance_stat(dfdist, cluster5)
calculate_distance_stat(dfdist, cluster6)
# Out:
# Este cluster tiene 62 muestras, con una distancia media de 122.29, rango [4 - 632]
# Este cluster tiene 37 muestras, con una distancia media de 46.33, rango [7 - 134]
# Este cluster tiene 32 muestras, con una distancia media de 153.39, rango [8 - 267]
# Este cluster tiene 22 muestras, con una distancia media de 43.96, rango [3 - 74]
# Este cluster tiene 12 muestras, con una distancia media de 86.59, rango [5 - 125]
# Este cluster tiene 10 muestras, con una distancia media de 124.69, rango [10 - 205]
# /home/pjsola/.conda/envs/develop/lib/python3.6/site-packages/pandas/core/indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
dfadist = pd.read_csv('/home/pjsola/google-drive-pedroscampoy/0_CNM_ISCIII/SEIMC_2020/CAR_SUR_cgWGS.allele_distance_matric.csv', index_col=0, header=None,  sep=",")

# %%
dfadist.shape
# Out:
# (224, 223)

# %%
# Out:
# '224'

# %%
dfadist[str(len(dfadist.index))] = np.nan

# %%
dfadist.shape
# Out:
# (224, 224)

# %%
dfadist.columns = dfadist.index

# %%
dfadist.head()
# Out:
# 0         A1507KPN  B0202KPN   G0101   G0108  G0104  D0010  B0201KPN  \
# 0
# A1507KPN       NaN       NaN     NaN     NaN    NaN    NaN       NaN
# B0202KPN    1920.0       NaN     NaN     NaN    NaN    NaN       NaN
# G0101       1910.0    1904.0     NaN     NaN    NaN    NaN       NaN
# G0108       1998.0    1991.0     1.0     NaN    NaN    NaN       NaN
# G0104       1992.0    1995.0  1840.0  1918.0    NaN    NaN       NaN
#
# 0         A0106KPN  A0301KPN  A0401KPN  A0402KPN  A0502KPN  A0506KPN  \
# 0
# A1507KPN       NaN       NaN       NaN       NaN       NaN       NaN
# B0202KPN       NaN       NaN       NaN       NaN       NaN       NaN
# G0101          NaN       NaN       NaN       NaN       NaN       NaN
# G0108          NaN       NaN       NaN       NaN       NaN       NaN
# G0104          NaN       NaN       NaN       NaN       NaN       NaN
#
# 0         A0706KPN  A0801KPN  A0802KPN  A0803KPN  A0804KPN  A0805KPN  \
# 0
# ...

# %%
#mask = dfadist[dfadist < 10].notnull()

# %%
dfadist[dfadist < 10].dropna(how='all')
# Out:
# 0         A1507KPN  B0202KPN  G0101  G0108  G0104  D0010  B0201KPN  A0106KPN  \
# 0
# G0108          NaN       NaN    1.0    NaN    NaN    NaN       NaN       NaN
# A0801KPN       NaN       NaN    NaN    NaN    NaN    NaN       NaN       NaN
# A0802KPN       NaN       NaN    NaN    NaN    NaN    NaN       NaN       NaN
# A0803KPN       NaN       NaN    NaN    NaN    NaN    NaN       NaN       NaN
# A0804KPN       NaN       NaN    NaN    NaN    NaN    NaN       NaN       NaN
# ...            ...       ...    ...    ...    ...    ...       ...       ...
# G0102          NaN       NaN    NaN    NaN    8.0    NaN       NaN       NaN
# G0103          NaN       NaN    NaN    NaN    5.0    NaN       NaN       NaN
# G0105          NaN       NaN    NaN    NaN    5.0    NaN       NaN       NaN
# G0203          NaN       NaN    NaN    NaN    NaN    NaN       NaN       NaN
# G0205          NaN       NaN    NaN    NaN    NaN    NaN       NaN       NaN
#
# ...

# %%
print("SNP DISTANCE")
calculate_distance_stat(dfdist, cluster1)
calculate_distance_stat(dfdist, cluster2)
calculate_distance_stat(dfdist, cluster3)
calculate_distance_stat(dfdist, cluster4)
print("ALLELE DISTANCE")
calculate_distance_stat(dfadist, cluster1)
calculate_distance_stat(dfadist, cluster2)
calculate_distance_stat(dfadist, cluster3)
calculate_distance_stat(dfadist, cluster4)
# Out:
# SNP DISTANCE
# Este cluster tiene 62 muestras, con una distancia media de 122.29, rango [4 - 632]
# Este cluster tiene 40 muestras, con una distancia media de 58.53, rango [7 - 182]
# Este cluster tiene 32 muestras, con una distancia media de 153.39, rango [8 - 267]
# Este cluster tiene 22 muestras, con una distancia media de 43.96, rango [3 - 74]
# ALLELE DISTANCE
# Este cluster tiene 62 muestras, con una distancia media de 46.73, rango [0 - 242]
# Este cluster tiene 40 muestras, con una distancia media de 70.42, rango [0 - 439]
# Este cluster tiene 32 muestras, con una distancia media de 72.82, rango [0 - 141]
# Este cluster tiene 22 muestras, con una distancia media de 20.93, rango [0 - 40]
# /home/pjsola/.conda/envs/develop/lib/python3.6/site-packages/pandas/core/indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# ...

# %%
print("SNP DISTANCE")
calculate_distance_stat(dfdist, cluster1)
calculate_distance_stat(dfdist, cluster2)
calculate_distance_stat(dfdist, cluster3)
calculate_distance_stat(dfdist, cluster4)
calculate_distance_stat(dfdist, cluster5)
calculate_distance_stat(dfdist, cluster6)
print("ALLELE DISTANCE")
calculate_distance_stat(dfadist, cluster1)
calculate_distance_stat(dfadist, cluster2)
calculate_distance_stat(dfadist, cluster3)
calculate_distance_stat(dfadist, cluster4)
calculate_distance_stat(dfadist, cluster5)
calculate_distance_stat(dfadist, cluster6)
# Out:
# SNP DISTANCE
# Este cluster tiene 62 muestras, con una distancia media de 122.29, rango [4 - 632]
# Este cluster tiene 37 muestras, con una distancia media de 46.33, rango [7 - 134]
# Este cluster tiene 32 muestras, con una distancia media de 153.39, rango [8 - 267]
# Este cluster tiene 22 muestras, con una distancia media de 43.96, rango [3 - 74]
# Este cluster tiene 12 muestras, con una distancia media de 86.59, rango [5 - 125]
# Este cluster tiene 10 muestras, con una distancia media de 124.69, rango [10 - 205]
# ALLELE DISTANCE
# Este cluster tiene 62 muestras, con una distancia media de 46.73, rango [0 - 242]
# Este cluster tiene 37 muestras, con una distancia media de 23.43, rango [0 - 76]
# Este cluster tiene 32 muestras, con una distancia media de 72.82, rango [0 - 141]
# Este cluster tiene 22 muestras, con una distancia media de 20.93, rango [0 - 40]
# Este cluster tiene 12 muestras, con una distancia media de 43.98, rango [0 - 65]
# ...

# %%
dfadist.loc[cluster2,cluster2]
# Out:
# 0         A0106KPN  A0301KPN  A0401KPN  A0402KPN  A0502KPN  A0506KPN  \
# 0
# A0106KPN       NaN       NaN       NaN       NaN       NaN       NaN
# A0301KPN      10.0       NaN       NaN       NaN       NaN       NaN
# A0401KPN      24.0      18.0       NaN       NaN       NaN       NaN
# A0402KPN      16.0      18.0      30.0       NaN       NaN       NaN
# A0502KPN      13.0      14.0      27.0      20.0       NaN       NaN
# A0506KPN      22.0      23.0      36.0      28.0      13.0       NaN
# A0706KPN      19.0      15.0      27.0      24.0      22.0      26.0
# A0801KPN      13.0       8.0      21.0      20.0      16.0      25.0
# A0802KPN      14.0      10.0      23.0      20.0      16.0      25.0
# A0803KPN      12.0       7.0      20.0      19.0      15.0      24.0
# A0804KPN      16.0      12.0      25.0      22.0      19.0      27.0
# A0805KPN      13.0      10.0      23.0      20.0      16.0      25.0
# ...

# %%
dfdist.loc[cluster2,cluster2]
# Out:
#           A0106KPN  A0301KPN  A0401KPN  A0402KPN  A0502KPN  A0506KPN  \
# A0106KPN       NaN       NaN       NaN       NaN       NaN       NaN
# A0301KPN      35.0       NaN       NaN       NaN       NaN       NaN
# A0401KPN      56.0      37.0       NaN       NaN       NaN       NaN
# A0402KPN      35.0      28.0      54.0       NaN       NaN       NaN
# A0502KPN      45.0      32.0      60.0      38.0       NaN       NaN
# A0506KPN      56.0      43.0      73.0      42.0      43.0       NaN
# A0706KPN      31.0      14.0      39.0      20.0      23.0      40.0
# A0801KPN      49.0      34.0      54.0      44.0      55.0      67.0
# A0802KPN      42.0      26.0      55.0      29.0      44.0      49.0
# A0803KPN      52.0      26.0      56.0      35.0      49.0      58.0
# A0804KPN      45.0      35.0      56.0      40.0      54.0      57.0
# A0805KPN      38.0      24.0      46.0      34.0      42.0      52.0
# A0806KPN      34.0      21.0      36.0      35.0      43.0      52.0
# ...

# %% [markdown]
# # Análisis final RESFINDER

# %%
kpnresfinder = import_ariba('/processing_Data/antibioticos/mperezv/ANALYSIS/KPNCARSUR/06-ariba/summary/out.summaryresfinder.csv')

# %%
kpnresfinder
# Out:
#           ARR_-  aac_3__II-  aac_6___Ib_cr+  aadA-  aadA-_1  aadA1+  aadA16  \
# name
# A0101KPN      0           1               1      0        0       0       0
# A0102KPN      0           0               0      0        0       0       0
# A0103KPN      0           0               1      0        0       0       0
# A0104KPN      0           0               0      0        0       0       0
# A0105KPN      0           1               1      0        0       0       0
# A0106KPN      0           0               1      0        0       0       0
# A0107KPN      0           1               1      0        0       0       0
# A0108KPN      0           1               1      0        0       0       0
# A0109KPN      0           1               1      0        0       0       0
# A0110KPN      0           1               1      0        0       0       0
# A0301KPN      0           0               0      0        0       0       0
# ...

# %%
list_resfinder_kpn = kpnresfinder.sum(axis = 0, skipna = True)
list_resfinder_kpn
# Out:
# ARR_-              13
# aac_3__II-         95
# aac_6___Ib_cr+    161
# aadA-              43
# aadA-_1             2
# aadA1+             25
# aadA16              7
# ant_2____Ia         3
# aph_3___Ia         46
# aph_3___VI-         2
# aph_3___XV          1
# aph_3____Ib       103
# aph_6__Id         105
# bla-                1
# bla-_3              1
# bla-_7             36
# blaCTX_M_-        151
# blaCTX_M_-_2        3
# blaKPC_-           47
# blaNDM_-            4
# blaOXA_-_23       163
# blaOXA_-_5        125
# blaOXA_9            1
# blaSHV_-          186
# blaTEM_-          114
# blaVIM_-           15
# catA1              47
# catA2               3
# catB2              10
# catB3               3
# cml-                1
# dfrA-               2
# dfrA-_2             1
# dfrA12             38
# dfrA14            110
# dfrA15              4
# dfrA1_1             1
# dfrA2-              8
# dfrB-              11
# fosA-_1           225
# mcr_9               1
# ...

# %%
print_stats(list_resfinder_kpn)
# Out:
# Nunero total:58, Maximo:225, , Minimo:1, Media:47.47

# %%
len(list_resfinder_kpn)
# Out:
# 58

# %%
len(list_res_kpn)
# Out:
# 61

# %%
list_resfinder_sample_kpn = kpnresfinder.sum(axis = 1, skipna = True)
list_resfinder_sample_kpn
# Out:
# name
# A0101KPN    15
# A0102KPN     5
# A0103KPN    10
# A0104KPN     5
# A0105KPN    16
# A0106KPN    10
# A0107KPN    16
# A0108KPN    16
# A0109KPN    15
# A0110KPN    16
# A0301KPN     7
# A0302KPN    12
# A0303KPN     7
# A0304KPN     7
# A0305KPN     8
# A0306KPN     8
# A0401KPN     8
# A0402KPN     6
# A0501KPN    14
# A0502KPN    16
# A0504KPN     5
# A0505KPN    18
# A0506KPN     6
# A0507KPN    11
# A0508KPN    15
# A0509KPN    13
# A0601KPN    16
# A0602KPN    16
# A0603KPN    14
# A0604KPN    16
# A0605KPN    14
# A0606KPN     6
# A0607KPN    24
# A0608KPN    16
# A0610KPN    11
# A0701KPN     9
# A0702KPN    13
# A0703KPN    14
# A0704KPN    15
# A0705KPN    11
# A0706KPN    16
# A0707KPN    14
# A0708KPN    13
# A0709KPN     6
# A0710KPN    13
# A0801KPN    11
# A0802KPN    10
# A0803KPN     8
# A0804KPN     9
# A0805KPN    17
# A0806KPN    10
# A0807KPN     8
# A0808KPN     8
# A0901KPN    13
# A1001KPN    12
# A1002KPN    16
# A1003KPN    12
# A1004KPN    20
# ...

# %%
print_stats(list_resfinder_sample_kpn)
# Out:
# Nunero total:229, Maximo:24, , Minimo:3, Media:12.02

# %%
kpnres.head()
# Out:
#           AMPH_Ecoli_Bla  Aac3_IIa_AGly  AacAad_AGly  AacAad_AGly_3  \
# name
# A0101KPN               0              1            0              1
# A0102KPN               0              0            0              0
# A0103KPN               0              0            0              1
# A0104KPN               0              0            0              0
# A0105KPN               0              1            0              1
#
#           AadA4_5_AGly  AadA_AGly  AadA_AGly_2  AadB_AGly  AmpC1_Ecoli_Bla  \
# name
# A0101KPN             0          0            0          0                0
# A0102KPN             0          0            0          0                0
# A0103KPN             0          0            0          0                0
# A0104KPN             0          0            0          0                0
# A0105KPN             0          0            0          0                0
#
#           AmpC2_Ecoli_Bla  AmpH_Bla  Aph3__Ia_AGly  AphA15_AGly  AphA6_AGly  \
# name
# ...

# %%
kpnres.filter(regex='Dfr.*', axis=1).sum(axis=1).mean()
# Out:
# 0.7685589519650655

# %%
kpnres.filter(regex='SHV*', axis=1).columns
# Out:
# Index(['SHV_OKP_LEN_Bla', 'SHV_OKP_LEN_Bla_1'], dtype='object')

# %%
chromosome_res = ['AMPH_Ecoli_Bla', 'AmpC1_Ecoli_Bla', 'AmpC2_Ecoli_Bla', 'AmpH_Bla', 'OqxA_Flq', 'OqxB_Flq', 'SHV_OKP_LEN_Bla', 'SHV_OKP_LEN_Bla_1']

# %%
kpnres.filter(chromosome_res, axis=1)
# Out:
#           AMPH_Ecoli_Bla  AmpC1_Ecoli_Bla  AmpC2_Ecoli_Bla  AmpH_Bla  \
# name
# A0101KPN               0                0                0         1
# A0102KPN               0                0                0         1
# A0103KPN               0                0                0         1
# A0104KPN               0                0                0         1
# A0105KPN               0                0                0         1
# A0106KPN               0                0                0         1
# A0107KPN               0                0                0         1
# A0108KPN               0                0                0         1
# A0109KPN               0                0                0         1
# A0110KPN               0                0                0         1
# A0301KPN               0                0                0         1
# A0302KPN               0                0                0         1
# ...

# %%
kpnresadquired = kpnres.drop(chromosome_res, axis=1)

# %%
kpnres.shape
# Out:
# (229, 61)

# %%
kpnresadquired.shape
# Out:
# (229, 53)

# %%
list_adquired_sample_kpn = kpnresadquired.sum(axis = 1, skipna = True)
list_adquired_sample_kpn
# Out:
# name
# A0101KPN    11
# A0102KPN     1
# A0103KPN     6
# A0104KPN     1
# A0105KPN    12
# A0106KPN     7
# A0107KPN    12
# A0108KPN    12
# A0109KPN    11
# A0110KPN    12
# A0301KPN     3
# A0302KPN     7
# A0303KPN     2
# A0304KPN     2
# A0305KPN     3
# A0306KPN     3
# A0401KPN     4
# A0402KPN     2
# A0501KPN    11
# A0502KPN    13
# A0504KPN     1
# A0505KPN    15
# A0506KPN     2
# A0507KPN     6
# A0508KPN    11
# A0509KPN     8
# A0601KPN    12
# A0602KPN    13
# A0603KPN    12
# A0604KPN    12
# A0605KPN    10
# A0606KPN     2
# A0607KPN    20
# A0608KPN    12
# A0610KPN     7
# A0701KPN     6
# A0702KPN    10
# A0703KPN    11
# A0704KPN    11
# A0705KPN     7
# A0706KPN    12
# A0707KPN    11
# A0708KPN    10
# A0709KPN     2
# A0710KPN    10
# A0801KPN     7
# A0802KPN     7
# A0803KPN     4
# A0804KPN     6
# A0805KPN    14
# A0806KPN     7
# A0807KPN     4
# A0808KPN     5
# A0901KPN     8
# A1001KPN     9
# A1002KPN    12
# A1003KPN     9
# A1004KPN    16
# ...

# %%
print_stats(list_adquired_sample_kpn)
# Out:
# Nunero total:229, Maximo:20, , Minimo:1, Media:8.50

# %%
kpnresadquired.filter(['A0607KPN'], axis=0)
# Out:
#           Aac3_IIa_AGly  AacAad_AGly  AacAad_AGly_3  AadA4_5_AGly  AadA_AGly  \
# name
# A0607KPN              1            0              1             1          0
#
#           AadA_AGly_2  AadB_AGly  Aph3__Ia_AGly  AphA15_AGly  AphA6_AGly  \
# name
# A0607KPN            0          0              0            0           0
#
#           Arr_Rif  CMY_Bla  CTX_M_1_Bla  CTX_M_9_Bla  CatA1_Phe  CatA2_Phe  \
# name
# A0607KPN        0        1            1            0          1          0
#
#           CatB2_Phe  CatBx_Phe  CmlA_Phe  DHA_Bla  DfrA1_Tmt  DfrA1_Tmt_1  \
# name
# A0607KPN          0          1         0        0          0            0
#
#           DfrA27_Tmt  DfrA5_Tmt  DfrA5_Tmt_1  DfrA7_Tmt  DfrA_Tmt  DfrB_Tmt  \
# name
# A0607KPN           0          1            0          1         0         0
#
#           KPC_1_Bla  MphA_MLS  MphE_MLS  MrdA_Bla  MsrE_MLS  NDM_1_Bla  \
# name
# A0607KPN          0         1         0         1         0          0
#
# ...
