# %%
import os
import pandas as pd
import numpy as np 


from Bio import Entrez
from Bio import SeqIO


from scipy.cluster import hierarchy
from scipy.cluster.hierarchy import fcluster

from sklearn.cluster import AgglomerativeClustering


import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ### Credits: https://www.drawingfromdata.com/making-a-pairwise-distance-matrix-with-pandas

# %%
def mash_pairwise_to_matrix(distance_file):
    df = pd.read_csv(distance_file, sep='\t', names=['reference_ID', 'query_ID', 'distance', 'p_value', 'shared_hashes'])
    dfpair = df[['reference_ID', 'query_ID', 'distance']]
    dist_matrix = dfpair.groupby(['reference_ID', 'query_ID']).mean().unstack()
    dist_matrix = dist_matrix.droplevel(0, axis=1)
    
    return dist_matrix

# %%
def matrix_to_cluster(dist_matrix, dist_thr=1):
    agglom = AgglomerativeClustering(distance_threshold = dist_thr, n_clusters = None, linkage = 'ward')
    agglom.fit(dist_matrix)
    clusters_scikit = agglom.labels_
    return clusters_scikit

# %%
distance_file = '/home/pjsola/Develop/PJSC_utils/data/ECO30_90.mash.distance.tab'

# %%
df = pd.read_csv(distance_file, sep='\t', names=['reference_ID', 'query_ID', 'distance', 'p_value', 'shared_hashes'])

# %%
df.shape
# Out:
# (1089, 5)

# %%
df.head(20)
# Out:
#      reference_ID       query_ID  distance  p_value shared_hashes
# 0   NZ_CP015021.1  NZ_CP015021.1  0.000000  0.0      1000/1000
# 1   NZ_CP015022.1  NZ_CP015021.1  0.004643  0.0      830/1000
# 2   NZ_CP015856.1  NZ_CP015021.1  0.004800  0.0      825/1000
# 3   K00826.1       NZ_CP015021.1  1.000000  1.0      0/1000
# 4   NZ_CP017252.1  NZ_CP015021.1  0.004674  0.0      829/1000
# 5   NZ_CP017670.1  NZ_CP015021.1  0.004737  0.0      827/1000
# 6   NZ_CP018238.1  NZ_CP015021.1  0.003344  0.0      873/1000
# 7   NZ_CP018240.1  NZ_CP015021.1  0.002998  0.0      885/1000
# 8   NZ_CP018246.1  NZ_CP015021.1  0.003141  0.0      880/1000
# 9   NZ_CP018244.1  NZ_CP015021.1  0.003170  0.0      879/1000
# 10  NZ_CP018253.1  NZ_CP015021.1  0.003141  0.0      880/1000
# 11  NZ_CP018248.1  NZ_CP015021.1  0.004118  0.0      847/1000
# 12  NZ_CP018242.1  NZ_CP015021.1  0.003141  0.0      880/1000
# 13  NZ_CP018251.1  NZ_CP015021.1  0.002799  0.0      892/1000
# 14  NZ_CP018626.1  NZ_CP015021.1  0.005119  0.0      815/1000
# 15  NZ_CP022688.1  NZ_CP015021.1  0.004864  0.0      823/1000
# 16  NZ_CP015816.1  NZ_CP015021.1  0.003256  0.0      876/1000
# 17  NZ_CP016626.1  NZ_CP015021.1  0.003519  0.0      867/1000
# 18  NZ_CP017435.1  NZ_CP015021.1  0.003936  0.0      853/1000
# 19  NZ_CP017437.1  NZ_CP015021.1  0.003936  0.0      853/1000

# %%
#df.to_dict('records')

# %%
dfpair = df[['reference_ID', 'query_ID', 'distance']]

# %%
dist_matrix = dfpair.groupby(['reference_ID', 'query_ID']).mean().unstack()

# %%
dist_matrix.shape
# Out:
# (33, 33)

# %%
dist_matrix.head()
# Out:
#                   distance                                            \
# query_ID          K00826.1 NC_007414.1 NC_013010.1 NZ_AVCD01000003.1
# reference_ID
# K00826.1           0.0      1.000000    1.000000    1.000000
# NC_007414.1        1.0      0.000000    0.002162    0.002271
# NC_013010.1        1.0      0.002162    0.000000    0.000410
# NZ_AVCD01000003.1  1.0      0.002271    0.000410    0.000000
# NZ_CM007618.1      1.0      0.002743    0.001083    0.001109
#
#                                                                            \
# query_ID          NZ_CM007618.1 NZ_CM007785.1 NZ_CM007786.1 NZ_CM007787.1
# reference_ID
# K00826.1           1.000000      1.000000      1.000000      1.000000
# NC_007414.1        0.002743      0.046501      0.025812      0.076299
# NC_013010.1        0.001083      0.045035      0.025241      0.075541
# NZ_AVCD01000003.1  0.001109      0.044718      0.025000      0.075918
# NZ_CM007618.1      0.000000      0.045194      0.024604      0.074799
#
#                                                                            \
# query_ID          NZ_CM007788.1 NZ_CP006633.1 NZ_CP010305.1 NZ_CP015021.1
# reference_ID
# K00826.1           1.000000      1.0           1.000000      1.000000
# NC_007414.1        0.035157      1.0           0.002189      0.004832
# NC_013010.1        0.034248      1.0           0.000024      0.003141
# NZ_AVCD01000003.1  0.033366      1.0           0.000434      0.003460
# NZ_CM007618.1      0.033804      1.0           0.001109      0.003966
#
#                                                                            \
# query_ID          NZ_CP015022.1 NZ_CP015816.1 NZ_CP015847.2 NZ_CP015856.1
# reference_ID
# K00826.1           1.000000      1.000000      1.000000      1.000000
# NC_007414.1        0.000144      0.002271      0.002326      0.000313
# NC_013010.1        0.002000      0.000096      0.000459      0.002135
# NZ_AVCD01000003.1  0.002108      0.000508      0.000192      0.002244
# NZ_CM007618.1      0.002630      0.001083      0.001160      0.002714
#
#                                                                            \
# query_ID          NZ_CP016626.1 NZ_CP017252.1 NZ_CP017435.1 NZ_CP017437.1
# reference_ID
# K00826.1           1.000000      1.000000      1.000000      1.000000
# NC_007414.1        0.002326      0.000168      0.002714      0.002714
# NC_013010.1        0.000459      0.002027      0.001058      0.001058
# NZ_AVCD01000003.1  0.000192      0.002135      0.001083      0.001083
# NZ_CM007618.1      0.001160      0.002658      0.000024      0.000024
#
#                                                                            \
# query_ID          NZ_CP017439.1 NZ_CP017670.1 NZ_CP018238.1 NZ_CP018240.1
# reference_ID
# K00826.1           1.000000      1.000000      1.000000      1.000000
# NC_007414.1        0.002714      0.000216      0.002162      0.002000
# NC_013010.1        0.001058      0.002081      0.000656      0.000288
# NZ_AVCD01000003.1  0.001083      0.002189      0.000731      0.000557
# NZ_CM007618.1      0.000024      0.002658      0.001211      0.000982
#
#                                                                            \
# query_ID          NZ_CP018242.1 NZ_CP018244.1 NZ_CP018246.1 NZ_CP018248.1
# reference_ID
# K00826.1           1.000000      1.000000      1.000000      1.000000
# NC_007414.1        0.002000      0.001973      0.002027      0.001575
# NC_013010.1        0.000459      0.000483      0.000434      0.001263
# NZ_AVCD01000003.1  0.000434      0.000459      0.000410      0.001237
# NZ_CM007618.1      0.000756      0.000781      0.000831      0.001575
#
#                                                                            \
# query_ID          NZ_CP018251.1 NZ_CP018253.1 NZ_CP018626.1 NZ_CP022688.1
# reference_ID
# K00826.1           1.000000      1.000000      1.000000      1.000000
# NC_007414.1        0.002027      0.001919      0.000508      0.000361
# NC_013010.1        0.000582      0.000434      0.002408      0.002244
# NZ_AVCD01000003.1  0.000706      0.000508      0.002519      0.002353
# NZ_CM007618.1      0.001134      0.000931      0.002998      0.002771
#
#
# query_ID          NZ_DS999999.1
# reference_ID
# K00826.1           1.000000
# NC_007414.1        0.000144
# NC_013010.1        0.002108
# NZ_AVCD01000003.1  0.002216
# NZ_CM007618.1      0.002686

# %%
dist_matrix.columns[0:5]
# Out:
# MultiIndex([('distance',          'K00826.1'),
#             ('distance',       'NC_007414.1'),
#             ('distance',       'NC_013010.1'),
#             ('distance', 'NZ_AVCD01000003.1'),
#             ('distance',     'NZ_CM007618.1')],
#            names=[None, 'query_ID'])

# %%
dist_matrix.index[0:5]
# Out:
# Index(['K00826.1', 'NC_007414.1', 'NC_013010.1', 'NZ_AVCD01000003.1',
#        'NZ_CM007618.1'],
#       dtype='object', name='reference_ID')

# %% [markdown]
# ### Drop level 0 (multiindex) equivalent to distance

# %%
#df.columns = [col[1] for col in df.columns]
dist_matrix = dist_matrix.droplevel(0, axis=1)

# %%
dist_matrix.columns[0:5]
# Out:
# Index(['K00826.1', 'NC_007414.1', 'NC_013010.1', 'NZ_AVCD01000003.1',
#        'NZ_CM007618.1'],
#       dtype='object', name='query_ID')

# %%
samples_test = ['K00826.1', 'NZ_CP018246.1', 'NZ_CP018248.1', 'NZ_CM007786.1' ]

# %%
dist_matrix.loc[samples_test,samples_test]
# Out:
# query_ID       K00826.1  NZ_CP018246.1  NZ_CP018248.1  NZ_CM007786.1
# reference_ID
# K00826.1       0.0       1.000000       1.000000       1.000000
# NZ_CP018246.1  1.0       0.000000       0.001007       0.025081
# NZ_CP018248.1  1.0       0.001007       0.000000       0.024214
# NZ_CM007786.1  1.0       0.025081       0.024214       0.000000

# %%
#dist_matrix.loc['NZ_CM007786.1']

# %%
Z = hierarchy.linkage(dist_matrix, 'complete')
# Out:
# /home/pjsola/.conda/envs/develop/lib/python3.6/site-packages/ipykernel_launcher.py:1: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   """Entry point for launching an IPython kernel.

# %%
dendro = hierarchy.dendrogram(Z)

# %%
labelList = dist_matrix.columns.tolist()
plt.rcParams['lines.linewidth'] = 8 #Dendrogram line with
plt.rcParams['xtick.major.size'] = 10 #Only affect to tick (line) size
plt.rcParams.update({'font.size': 30}) #Increase x tick label size
#plt.tick_params(labelsize=30)
plt.figure(figsize=(30, 50))
plt.ylabel('sequences', fontsize=30)
plt.xlabel('distance', fontsize=30)

hierarchy.dendrogram(Z, labels=labelList, orientation='left', distance_sort='descending', show_leaf_counts=True, color_threshold=1, leaf_font_size=20)

plt.show
plt.savefig('test_plasmid_distance.png', format="png")
plt.savefig('test_plasmid_distance.svg', format="svg")

# %%
#sns.clustermap(dist_matrix, cmap="YlGnBu", figsize=(20, 20))

# %%
max_d = 1
clusters_scipy = fcluster(Z, max_d, criterion='distance')

# %%
clusters_scipy
# Out:
# array([1, 3, 3, 3, 3, 4, 5, 6, 4, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3], dtype=int32)

# %%
df_cl_scy = pd.DataFrame()
df_cl_scy['aacc'] =  dist_matrix.index
df_cl_scy['cluster'] = clusters_scipy

# %%
#df_cl_scy.sort_values(by=['cluster'])
df_cl_scy
# Out:
#                  aacc  cluster
# 0   K00826.1           1
# 1   NC_007414.1        3
# 2   NC_013010.1        3
# 3   NZ_AVCD01000003.1  3
# 4   NZ_CM007618.1      3
# 5   NZ_CM007785.1      4
# 6   NZ_CM007786.1      5
# 7   NZ_CM007787.1      6
# 8   NZ_CM007788.1      4
# 9   NZ_CP006633.1      2
# 10  NZ_CP010305.1      3
# 11  NZ_CP015021.1      3
# 12  NZ_CP015022.1      3
# 13  NZ_CP015816.1      3
# 14  NZ_CP015847.2      3
# 15  NZ_CP015856.1      3
# 16  NZ_CP016626.1      3
# 17  NZ_CP017252.1      3
# 18  NZ_CP017435.1      3
# 19  NZ_CP017437.1      3
# 20  NZ_CP017439.1      3
# 21  NZ_CP017670.1      3
# 22  NZ_CP018238.1      3
# 23  NZ_CP018240.1      3
# 24  NZ_CP018242.1      3
# 25  NZ_CP018244.1      3
# 26  NZ_CP018246.1      3
# 27  NZ_CP018248.1      3
# 28  NZ_CP018251.1      3
# 29  NZ_CP018253.1      3
# 30  NZ_CP018626.1      3
# 31  NZ_CP022688.1      3
# 32  NZ_DS999999.1      3

# %%
def acc_to_len_id(row):
    accession_number = row.aacc
    Entrez.email = "A.N.Other@example.com"
    try:
        handle = Entrez.efetch(db="nucleotide", id=accession_number, rettype="fasta", retmode="text")
        record = SeqIO.read(handle, "fasta")
        handle.close()
        #print("Downloaded: " + record.description)
        #print("Downloaded: " + str(len(record)))
        #return record
        description = ' '.join(record.description.split()[3:])
        species = ' '.join(record.description.split()[1:3])
        return len(record), species, description
    except:
        print(record.id + " failed to download")
        sys.exit(1)
    
    '''    
    #SeqIO.write(record, output_handle, "fasta")
    '''

# %%
#acc_to_len_id('K00826.1')

# %%
df_cl_scy[['length', 'species', 'description']] = df_cl_scy.apply(acc_to_len_id, axis=1, result_type="expand")

# %%
df_cl_scy
# Out:
#                  aacc  cluster  length           species  \
# 0   K00826.1           1        4012    Escherichia coli
# 1   NC_007414.1        3        92077   Escherichia coli
# 2   NC_013010.1        3        94601   Escherichia coli
# 3   NZ_AVCD01000003.1  3        98062   Escherichia coli
# 4   NZ_CM007618.1      3        92545   Escherichia coli
# 5   NZ_CM007785.1      4        23446   Escherichia coli
# 6   NZ_CM007786.1      5        38633   Escherichia coli
# 7   NZ_CM007787.1      6        9382    Escherichia coli
# 8   NZ_CM007788.1      4        32634   Escherichia coli
# 9   NZ_CP006633.1      2        3319    Escherichia coli
# 10  NZ_CP010305.1      3        94730   Escherichia coli
# 11  NZ_CP015021.1      3        81401   Escherichia coli
# 12  NZ_CP015022.1      3        95170   Escherichia coli
# 13  NZ_CP015816.1      3        95910   Escherichia coli
# 14  NZ_CP015847.2      3        95599   Escherichia coli
# 15  NZ_CP015856.1      3        115432  Escherichia coli
# 16  NZ_CP016626.1      3        95598   Escherichia coli
# 17  NZ_CP017252.1      3        92691   Escherichia coli
# 18  NZ_CP017435.1      3        92624   Escherichia coli
# 19  NZ_CP017437.1      3        92565   Escherichia coli
# 20  NZ_CP017439.1      3        92596   Escherichia coli
# 21  NZ_CP017670.1      3        92755   Escherichia coli
# 22  NZ_CP018238.1      3        91420   Escherichia coli
# 23  NZ_CP018240.1      3        94170   Escherichia coli
# 24  NZ_CP018242.1      3        92495   Escherichia coli
# 25  NZ_CP018244.1      3        92522   Escherichia coli
# 26  NZ_CP018246.1      3        95341   Escherichia coli
# 27  NZ_CP018248.1      3        91353   Escherichia coli
# 28  NZ_CP018251.1      3        91789   Escherichia coli
# 29  NZ_CP018253.1      3        95229   Escherichia coli
# 30  NZ_CP018626.1      3        107692  Escherichia coli
# 31  NZ_CP022688.1      3        92032   Escherichia coli
# 32  NZ_DS999999.1      3        92381   Escherichia coli
#
#                                                                                description
# 0   plasmid pCM959 complete sequence
# 1   O157:H7 str. EDL933 plasmid pO157, complete sequence
# 2   O157:H7 str. TW14359 plasmid pO157, complete sequence
# 3   O157:H7 str. F8092B plasmid pO157, whole genome shotgun sequence
# 4   O157:H7 strain 1175 plasmid pO157, whole genome shotgun sequence
# 5   O157:H7 strain LEN02-0647-1 plasmid p_IncFIA, whole genome shotgun sequence
# 6   O157:H7 strain LEN02-0647-1 plasmid p_IncFIB, whole genome shotgun sequence
# 7   O157:H7 strain LEN02-0647-1 plasmid p_IncFII, whole genome shotgun sequence
# 8   O157:H7 strain LEN02-9121-1 plasmid p_IncFIA, whole genome shotgun sequence
# 9   PCN033 plasmid p1PCN033, complete sequence
# 10  O157:H7 str. SS52 plasmid p0157, complete sequence
# 11  strain 28RC1 plasmid p28RC1, complete sequence
# 12  strain SRCC 1675 plasmid pSRCC 1675, complete sequence
# 13  O157:H7 strain JEONG-1266 plasmid p0157, complete sequence
# 14  O157:H7 strain FRIK2069 plasmid p0157, complete sequence
# 15  strain EDL933-1 plasmid pO157, complete sequence
# 16  O157:H7 strain FRIK944 plasmid p0157, complete sequence
# 17  strain NADC 5570/86-24/6564 isolate wild type plasmid pO157, complete sequence
# 18  O157:H7 strain 1130 plasmid pO157, complete sequence
# 19  O157:H7 strain 2149 plasmid pO157, complete sequence
# 20  O157:H7 strain 2159 plasmid pO157, complete sequence
# 21  strain PA20 plasmid pO157, complete sequence
# 22  strain 155 plasmid pO157, complete sequence
# 23  strain 272 plasmid pO157, complete sequence
# 24  strain 319 plasmid pO157, complete sequence
# 25  strain 350 plasmid pO157, complete sequence
# 26  strain 472 plasmid pO157, complete sequence
# 27  strain 7784 plasmid pO157, complete sequence
# 28  strain 10671 plasmid pO157, complete sequence
# 29  strain 9000 plasmid pO157, complete sequence
# 30  strain FORC_044 plasmid pFORC44_2, complete sequence
# 31  strain CDC#03-98 plasmid p0157, complete sequence
# 32  O157:H7 str. TW14588 plasmid pTW14588 scf_1117778227960, whole genome shotgun sequence

# %%
plt.rcParams.update(plt.rcParamsDefault)

n_clusters = len(df_cl_scy.cluster.unique()) + 1
colors = cm.rainbow(np.linspace(0, 1, n_clusters))
cluster_labels = list(range(0, n_clusters))

# Crear una figura de 6 pulgadas (aprox 15cm) por 4 pulgadas (aprox 10cm).
plt.figure(figsize=(16,14))

for color, label in zip(colors, cluster_labels):
    subset = df_cl_scy[df_cl_scy.cluster == label]
    for i in subset.index:
            plt.text(subset.cluster[i], subset.length[i],str(subset['aacc'][i]), rotation=20) 
    plt.scatter(subset.cluster, subset.length, s= subset.length/100, c=color, label='cluster'+str(label),alpha=0.5)
#    plt.scatter(subset.horsepow, subset.mpg)
plt.legend()
plt.title('Clusters')
plt.xlabel('horsepow')
plt.ylabel('mpg')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# Text(0, 0.5, 'mpg')

# %% [markdown]
# ## Clustering using scikit-learn

# %%
agglom = AgglomerativeClustering(distance_threshold = 1, n_clusters = None, linkage = 'ward')
agglom.fit(dist_matrix)
clusters_scikit = agglom.labels_
clusters_scikit
# Out:
# /home/pjsola/.conda/envs/develop/lib/python3.6/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# array([5, 2, 2, 2, 2, 0, 4, 3, 0, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2])

# %%
unique, counts = np.unique(clusters_scikit, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0: 2, 1: 1, 2: 27, 3: 1, 4: 1, 5: 1}

# %%
df_cl_scyk = pd.DataFrame()
df_cl_scyk['aacc'] =  dist_matrix.index
df_cl_scyk['cluster'] = clusters_scikit

# %%
df_cl_scyk.head()
# Out:
#                 aacc  cluster
# 0  K00826.1           3
# 1  NC_007414.1        2
# 2  NC_013010.1        2
# 3  NZ_AVCD01000003.1  2
# 4  NZ_CM007618.1      2

# %%
df_cl_scyk[['length', 'species', 'description']] = df_cl_scyk.apply(acc_to_len_id, axis=1, result_type="expand")

# %%
df_cl_scyk
# Out:
#                  aacc  cluster  length           species  \
# 0   K00826.1           3        4012    Escherichia coli
# 1   NC_007414.1        2        92077   Escherichia coli
# 2   NC_013010.1        2        94601   Escherichia coli
# 3   NZ_AVCD01000003.1  2        98062   Escherichia coli
# 4   NZ_CM007618.1      2        92545   Escherichia coli
# 5   NZ_CM007785.1      0        23446   Escherichia coli
# 6   NZ_CM007786.1      4        38633   Escherichia coli
# 7   NZ_CM007787.1      5        9382    Escherichia coli
# 8   NZ_CM007788.1      0        32634   Escherichia coli
# 9   NZ_CP006633.1      1        3319    Escherichia coli
# 10  NZ_CP010305.1      2        94730   Escherichia coli
# 11  NZ_CP015021.1      2        81401   Escherichia coli
# 12  NZ_CP015022.1      2        95170   Escherichia coli
# 13  NZ_CP015816.1      2        95910   Escherichia coli
# 14  NZ_CP015847.2      2        95599   Escherichia coli
# 15  NZ_CP015856.1      2        115432  Escherichia coli
# 16  NZ_CP016626.1      2        95598   Escherichia coli
# 17  NZ_CP017252.1      2        92691   Escherichia coli
# 18  NZ_CP017435.1      2        92624   Escherichia coli
# 19  NZ_CP017437.1      2        92565   Escherichia coli
# 20  NZ_CP017439.1      2        92596   Escherichia coli
# 21  NZ_CP017670.1      2        92755   Escherichia coli
# 22  NZ_CP018238.1      2        91420   Escherichia coli
# 23  NZ_CP018240.1      2        94170   Escherichia coli
# 24  NZ_CP018242.1      2        92495   Escherichia coli
# 25  NZ_CP018244.1      2        92522   Escherichia coli
# 26  NZ_CP018246.1      2        95341   Escherichia coli
# 27  NZ_CP018248.1      2        91353   Escherichia coli
# 28  NZ_CP018251.1      2        91789   Escherichia coli
# 29  NZ_CP018253.1      2        95229   Escherichia coli
# 30  NZ_CP018626.1      2        107692  Escherichia coli
# 31  NZ_CP022688.1      2        92032   Escherichia coli
# 32  NZ_DS999999.1      2        92381   Escherichia coli
#
#                                                                                description
# 0   plasmid pCM959 complete sequence
# 1   O157:H7 str. EDL933 plasmid pO157, complete sequence
# 2   O157:H7 str. TW14359 plasmid pO157, complete sequence
# 3   O157:H7 str. F8092B plasmid pO157, whole genome shotgun sequence
# 4   O157:H7 strain 1175 plasmid pO157, whole genome shotgun sequence
# 5   O157:H7 strain LEN02-0647-1 plasmid p_IncFIA, whole genome shotgun sequence
# 6   O157:H7 strain LEN02-0647-1 plasmid p_IncFIB, whole genome shotgun sequence
# 7   O157:H7 strain LEN02-0647-1 plasmid p_IncFII, whole genome shotgun sequence
# 8   O157:H7 strain LEN02-9121-1 plasmid p_IncFIA, whole genome shotgun sequence
# 9   PCN033 plasmid p1PCN033, complete sequence
# 10  O157:H7 str. SS52 plasmid p0157, complete sequence
# 11  strain 28RC1 plasmid p28RC1, complete sequence
# 12  strain SRCC 1675 plasmid pSRCC 1675, complete sequence
# 13  O157:H7 strain JEONG-1266 plasmid p0157, complete sequence
# 14  O157:H7 strain FRIK2069 plasmid p0157, complete sequence
# 15  strain EDL933-1 plasmid pO157, complete sequence
# 16  O157:H7 strain FRIK944 plasmid p0157, complete sequence
# 17  strain NADC 5570/86-24/6564 isolate wild type plasmid pO157, complete sequence
# 18  O157:H7 strain 1130 plasmid pO157, complete sequence
# 19  O157:H7 strain 2149 plasmid pO157, complete sequence
# 20  O157:H7 strain 2159 plasmid pO157, complete sequence
# 21  strain PA20 plasmid pO157, complete sequence
# 22  strain 155 plasmid pO157, complete sequence
# 23  strain 272 plasmid pO157, complete sequence
# 24  strain 319 plasmid pO157, complete sequence
# 25  strain 350 plasmid pO157, complete sequence
# 26  strain 472 plasmid pO157, complete sequence
# 27  strain 7784 plasmid pO157, complete sequence
# 28  strain 10671 plasmid pO157, complete sequence
# 29  strain 9000 plasmid pO157, complete sequence
# 30  strain FORC_044 plasmid pFORC44_2, complete sequence
# 31  strain CDC#03-98 plasmid p0157, complete sequence
# 32  O157:H7 str. TW14588 plasmid pTW14588 scf_1117778227960, whole genome shotgun sequence

# %%
plt.rcParams.update(plt.rcParamsDefault)

n_clusters = len(df_cl_scyk.cluster.unique()) + 1
colors = cm.rainbow(np.linspace(0, 1, n_clusters))
cluster_labels = list(range(0, n_clusters))

# Crear una figura de 6 pulgadas (aprox 15cm) por 4 pulgadas (aprox 10cm).
plt.figure(figsize=(16,14))

for color, label in zip(colors, cluster_labels):
    subset = df_cl_scyk[df_cl_scyk.cluster == label]
    for i in subset.index:
            plt.text(subset.cluster[i], subset.length[i],str(subset['aacc'][i]), rotation=20) 
    plt.scatter(subset.cluster, subset.length, s= subset.length/100, c=color, label='cluster'+str(label),alpha=0.5)
#    plt.scatter(subset.horsepow, subset.mpg)
plt.legend()
plt.title('Clusters')
plt.xlabel('cluster')
plt.ylabel('length')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# Text(0, 0.5, 'length')

# %% [markdown]
# ## EJEMPLO CON SALMONELLA

# %%
sen30_file = "/home/pjsola/Develop/PJSC_utils/data/SEN30.mash.distance.tab"
sen_dist_matrix = mash_pairwise_to_matrix(sen30_file)

# %%
sen_dist_matrix
# Out:
# query_ID       K00826.1  NC_002305.1  NC_003384.1  NC_003385.1  NC_009981.1  \
# reference_ID
# K00826.1       0.0       1.000000     1.000000     1.000000     1.000000
# NC_002305.1    1.0       0.000000     0.009326     1.000000     0.009855
# NC_003384.1    1.0       0.009326     0.000000     1.000000     0.003490
# NC_003385.1    1.0       1.000000     1.000000     0.000000     1.000000
# NC_009981.1    1.0       0.009855     0.003490     1.000000     0.000000
# NC_013365.1    1.0       0.009086     0.002912     1.000000     0.001522
# NZ_LT883154.1  1.0       1.000000     1.000000     0.000288     1.000000
# NZ_LT904853.1  1.0       1.000000     1.000000     0.000313     1.000000
# NZ_LT904874.1  1.0       1.000000     1.000000     1.000000     1.000000
# NZ_LT904880.1  1.0       1.000000     1.000000     0.000000     1.000000
# NZ_LT904895.1  1.0       1.000000     1.000000     0.000508     1.000000
#
# query_ID       NC_013365.1  NZ_LT883154.1  NZ_LT904853.1  NZ_LT904874.1  \
# reference_ID
# K00826.1       1.000000     1.000000       1.000000       1.0
# NC_002305.1    0.009086     1.000000       1.000000       1.0
# NC_003384.1    0.002912     1.000000       1.000000       1.0
# NC_003385.1    1.000000     0.000288       0.000313       1.0
# NC_009981.1    0.001522     1.000000       1.000000       1.0
# NC_013365.1    0.000000     1.000000       1.000000       1.0
# NZ_LT883154.1  1.000000     0.000000       0.000024       1.0
# NZ_LT904853.1  1.000000     0.000024       0.000000       1.0
# NZ_LT904874.1  1.000000     1.000000       1.000000       0.0
# NZ_LT904880.1  1.000000     0.000288       0.000313       1.0
# NZ_LT904895.1  1.000000     0.000216       0.000240       1.0
#
# query_ID       NZ_LT904880.1  NZ_LT904895.1
# reference_ID
# K00826.1       1.000000       1.000000
# NC_002305.1    1.000000       1.000000
# NC_003384.1    1.000000       1.000000
# NC_003385.1    0.000000       0.000508
# NC_009981.1    1.000000       1.000000
# NC_013365.1    1.000000       1.000000
# NZ_LT883154.1  0.000288       0.000216
# NZ_LT904853.1  0.000313       0.000240
# NZ_LT904874.1  1.000000       1.000000
# NZ_LT904880.1  0.000000       0.000508
# NZ_LT904895.1  0.000508       0.000000

# %%
sen_cluster = matrix_to_cluster(sen_dist_matrix)
# Out:
# /home/pjsola/.conda/envs/develop/lib/python3.6/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')

# %%
sen_cluster.sort()
sen_cluster
# Out:
# array([0, 0, 0, 0, 1, 1, 1, 1, 1, 2, 3])

# %%
senunique, sencounts = np.unique(sen_cluster, return_counts=True)
dict(zip(senunique, sencounts))
# Out:
# {0: 4, 1: 5, 2: 1, 3: 1}

# %%
df_cl_scyk_sen = pd.DataFrame()
df_cl_scyk_sen['aacc'] =  sen_dist_matrix.index
df_cl_scyk_sen['cluster'] = sen_cluster
df_cl_scyk_sen[['length', 'species', 'description']] = df_cl_scyk_sen.apply(acc_to_len_id, axis=1, result_type="expand")

# %%
df_cl_scyk_sen.sort_values(by=['cluster', 'length'], ascending=[True, False], inplace=True)
df_cl_scyk_sen
# Out:
#              aacc  cluster  length              species  \
# 2   NC_003384.1    0        218160  Salmonella enterica
# 4   NC_009981.1    0        208409  Salmonella enterica
# 5   NC_013365.1    0        204604  Escherichia coli
# 1   NC_002305.1    0        180461  Salmonella typhi
# 6   NZ_LT883154.1  1        106706  Salmonella enterica
# 7   NZ_LT904853.1  1        106704  Salmonella enterica
# 10  NZ_LT904895.1  1        106704  Salmonella enterica
# 3   NC_003385.1    1        106516  Salmonella enterica
# 9   NZ_LT904880.1  1        106516  Salmonella enterica
# 8   NZ_LT904874.1  2        2090    Salmonella enterica
# 0   K00826.1       3        4012    Escherichia coli
#
#                                                                   description
# 2   subsp. enterica serovar Typhi str. CT18 plasmid pHCM1, complete sequence
# 4   subsp. enterica serovar Choleraesuis plasmid pMAK1, complete sequence
# 5   O111:H- str. 11128 plasmid pO111_1, complete sequence
# 1   plasmid R27, complete sequence
# 6   subsp. enterica serovar Typhi strain ERL12148 genome assembly, plasmid: 2
# 7   subsp. enterica serovar Typhi strain TY585 genome assembly, plasmid: 2
# 10  subsp. enterica serovar Typhi strain ERL12960 genome assembly, plasmid: 2
# 3   subsp. enterica serovar Typhi str. CT18 plasmid pHCM2, complete sequence
# 9   subsp. enterica serovar Typhi strain ty3-193 genome assembly, plasmid: 3
# 8   subsp. enterica serovar Typhi strain ERL11909 genome assembly, plasmid: 3
# 0   plasmid pCM959 complete sequence

# %%
plt.rcParams.update(plt.rcParamsDefault)

n_clusters = 0
n_clusters = len(df_cl_scyk_sen.cluster.unique()) + 1
colors = cm.rainbow(np.linspace(0, 1, n_clusters))
cluster_labels = list(range(0, n_clusters))

# Crear una figura de 6 pulgadas (aprox 15cm) por 4 pulgadas (aprox 10cm).
plt.figure(figsize=(16,14))

for color, label in zip(colors, cluster_labels):
    subset = df_cl_scyk_sen[df_cl_scyk_sen.cluster == label]
    for i in subset.index:
            plt.text(subset.cluster[i], subset.length[i],str(subset['aacc'][i]), rotation=20) 
    plt.scatter(subset.cluster, subset.length, s= subset.length/100, c=color, label='cluster'+str(label),alpha=0.5)
#    plt.scatter(subset.horsepow, subset.mpg)
plt.legend()
plt.title('Clusters')
plt.xlabel('cluster')
plt.ylabel('length')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# Text(0, 0.5, 'length')

# %%
df_cl_scyk_sen.groupby('cluster').first()
# Out:
#                   aacc  length              species  \
# cluster
# 0        NC_003384.1    218160  Salmonella enterica
# 1        NZ_LT883154.1  106706  Salmonella enterica
# 2        NZ_LT904874.1  2090    Salmonella enterica
# 3        K00826.1       4012    Escherichia coli
#
#                                                                        description
# cluster
# 0        subsp. enterica serovar Typhi str. CT18 plasmid pHCM1, complete sequence
# 1        subsp. enterica serovar Typhi strain ERL12148 genome assembly, plasmid: 2
# 2        subsp. enterica serovar Typhi strain ERL11909 genome assembly, plasmid: 3
# 3        plasmid pCM959 complete sequence

# %%
df_cl_scyk_sen.groupby('cluster').head(2)
# Out:
#             aacc  cluster  length              species  \
# 2  NC_003384.1    0        218160  Salmonella enterica
# 4  NC_009981.1    0        208409  Salmonella enterica
# 6  NZ_LT883154.1  1        106706  Salmonella enterica
# 7  NZ_LT904853.1  1        106704  Salmonella enterica
# 8  NZ_LT904874.1  2        2090    Salmonella enterica
# 0  K00826.1       3        4012    Escherichia coli
#
#                                                                  description
# 2  subsp. enterica serovar Typhi str. CT18 plasmid pHCM1, complete sequence
# 4  subsp. enterica serovar Choleraesuis plasmid pMAK1, complete sequence
# 6  subsp. enterica serovar Typhi strain ERL12148 genome assembly, plasmid: 2
# 7  subsp. enterica serovar Typhi strain TY585 genome assembly, plasmid: 2
# 8  subsp. enterica serovar Typhi strain ERL11909 genome assembly, plasmid: 3
# 0  plasmid pCM959 complete sequence

# %%
#dict_test = dict(list(df_cl_scyk_sen.reset_index(drop=True).groupby('cluster')['aacc']))

# %%
#df_cl_scyk_sen.groupby('cluster')['aacc'].agg(lambda x: list(x)).reset_index(name='accs')
df_cl_scyk_sen.groupby('cluster')['aacc'].apply(list).reset_index(name='accs')
# Out:
#    cluster  \
# 0  0
# 1  1
# 2  2
# 3  3
#
#                                                                         accs
# 0  [NC_003384.1, NC_009981.1, NC_013365.1, NC_002305.1]
# 1  [NZ_LT883154.1, NZ_LT904853.1, NZ_LT904895.1, NC_003385.1, NZ_LT904880.1]
# 2  [NZ_LT904874.1]
# 3  [K00826.1]
